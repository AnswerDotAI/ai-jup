# %%
import random

# %%
a = random.randint(0, 100)

# %% [markdown]
# What is the value of $`a`?

# %% [markdown]
# The value of 96 is simply 96.
#
# In your code, the variable `a` has been assigned the value 96 (which was randomly generated between 0 and 100).
#
# If you're asking about properties or representations of the number 96, here are some facts:
#
# ```python
# print(f"Decimal: {a}")
# print(f"Binary: {bin(a)}")
# print(f"Hexadecimal: {hex(a)}")
# print(f"Octal: {oct(a)}")
# print(f"Square: {a**2}")
# print(f"Square root: {a**0.5}")
# print(f"Factors: {[i for i in range(1, a+1) if a % i == 0]}")
# ```

# %%
a
# Out:
# 96
